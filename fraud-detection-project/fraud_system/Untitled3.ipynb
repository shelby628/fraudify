# %%
transaction_data = {
    "step": 13,
    "amount": 6000,
    "oldbalanceOrg": 13000,
    "newbalanceOrig": 7000,
    "oldbalanceDest": 0,
    "newbalanceDest": 6000,
    "type_CASH_OUT": 1,
    "type_DEBIT": 0,
    "type_PAYMENT": 0,
    "type_TRANSFER": 0
}

# %%
import requests
import json

url = "http://127.0.0.1:8000/api/predict/"

admin_headers = {
    "Authorization": "Token acad20d2ddbfe38c8332567bd53816df00695fd3",
    "Content-Type": "application/json"
}

response = requests.post(url, headers=admin_headers, data=json.dumps(transaction_data))
print("Admin response:", response.json())
# Out:
# Admin response: {'status': 'success', 'decision': 'APPROVE', 'reason': 'Low fraud probability at Stage 2', 'meta': {'stage': 'unknown', 'model_version': 'v1.0'}, 'scores': {'stage1_probability': None, 'stage2_probability': None}}

# %%
import requests
import json

url = "http://127.0.0.1:8000/api/predict/"

admin_headers = {
    "Authorization": "Token d67a2e002528aca932f2c5ae42c5d895bfd63d6e",
    "Content-Type": "application/json"
}

response = requests.post(url, headers=admin_headers, data=json.dumps(transaction_data))
print("Admin response:", response.json())
# Out:
# Admin response: {'status': 'success', 'decision': 'APPROVE', 'reason': 'Low fraud probability at Stage 2'}
