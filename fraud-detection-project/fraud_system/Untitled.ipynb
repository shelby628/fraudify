# %%
import requests

# Replace with the token you generated
token = "ac5721c2fde0f59e07d8bdbe4001c9d39942b2c9"

headers = {
    "Authorization": f"Token {token}",
    "Content-Type": "application/json"
}

transaction = {
    "step": 13,
    "amount": 13000,
    "oldbalanceOrg": 13000,
    "oldbalanceDest": 0,
    "newbalanceDest": 6000,
    "type_CASH_OUT": 1,
    "type_DEBIT": 0,
    "type_PAYMENT": 0,
    "type_TRANSFER": 0
}

response = requests.post(
    "http://127.0.0.1:8000/api/predict/",
    headers=headers,
    json=transaction
)

print(response.status_code)
print(response.json())
