# %%
from pipeline import process_transaction

# %%
transaction = {
    "step": 13,
    "oldbalanceOrg": 13000,
    "oldbalanceDest": 0,
    "newbalanceDest": 6000,
    "type_CASH_OUT": 1,
    "type_DEBIT": 0,
    "type_PAYMENT": 0,
    "type_TRANSFER": 0
}

result = process_transaction(transaction)
print(result)
# Out:
# {'decision': 'REVIEW', 'stage': 'Fallback', 'reason': 'Missing required field: amount'}

# %%
result =  process_transaction(transaction)
print(result)
# Out:
# {'decision': 'APPROVE', 'stage': 'Stage 2', 'reason': 'Stage 2 probability-based decision'}
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
results = []

# %%
for _, row in df_test.iterrows():
# Out:
#   Cell In[4], line 1
#     for _, row in df_test.iterrows():
#                                      ^
# _IncompleteInputError: incomplete input

# %%
df_test = df.sample(500, random_state=42)
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_test = df.sample(500, random_state=42)
#
# NameError: name 'df' is not defined
